# %% [markdown]
# # Python与PyTorch深度学习完整指南 🐍🔥
#
# 欢迎来到Python和PyTorch的学习之旅！本笔记本将带您从Python基础语法开始，逐步深入到PyTorch深度学习框架的使用。
#
# ## 📚 学习内容概览
#
# 1. **Python基础** - 语法、数据类型、控制结构
# 2. **数据科学工具** - NumPy、Pandas、Matplotlib
# 3. **PyTorch深度学习** - 张量操作、自动梯度、神经网络构建
# 4. **深度学习进阶** - CNN, RNN
# 5. **实战项目** - 图像分类和情感分析
#
# ## 🎯 学习目标
#
# - 掌握Python编程基础
# - 熟悉数据科学常用库
# - 理解深度学习基本概念
# - 能够使用PyTorch构建和训练各种模型

# %% [markdown]
# ## 1. Python基础语法 📝

# %%
# 1.1 变量和基本运算
print("=== Python变量基础 ===")
name = "小明"
age = 25
print(f"姓名: {name}, 年龄: {age}")

# %% [markdown]
# ## 2. 数据科学工具 🔬

# %% [markdown]
# ### 2.1 NumPy
# NumPy是Python科学计算的核心库。

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
print(f"NumPy Array: {arr}")
print(f"Shape: {arr.shape}")

# %% [markdown]
# ### 2.2 Pandas
# Pandas用于数据处理和分析。

# %%
import pandas as pd
data = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=data)
print("Pandas DataFrame:")
print(df)

# %% [markdown]
# ### 2.3 Matplotlib
# Matplotlib用于数据可视化。

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# ## 3. PyTorch基础 🔥

# %%
import torch
x = torch.rand(5, 3)
print(f"PyTorch Tensor:\n{x}")

# %% [markdown]
# ### 3.1 自动求导 (Autograd)

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x + 2
z = y * y * 3
out = z.mean()
out.backward()
print(f"Gradient of x:\n{x.grad}")

# %% [markdown]
# ### 3.2 构建神经网络

# %%
import torch.nn as nn
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(10, 5)
        self.fc2 = nn.Linear(5, 2)
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        return self.fc2(x)
net = SimpleNet()
print(net)

# %% [markdown]
# ## 4. 深度学习进阶 🚀

# %% [markdown]
# ### 4.1 卷积神经网络 (CNN)
# CNNs are primarily used for image processing tasks.

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(20 * 12 * 12, 10)
    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = x.view(-1, 20 * 12 * 12)
        x = self.fc1(x)
        return x
cnn = SimpleCNN()
print(cnn)

# %% [markdown]
# ### 4.2 循环神经网络 (RNN)
# RNNs are used for sequential data.

# %%
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])
        return out
rnn = SimpleRNN(10, 20, 1)
print(rnn)

# %% [markdown]
# ## 5. 实战项目 💼
# Now it's time to apply your knowledge. Check out the projects in the `05_projects` directory:
#
# - **Image Classification**: Train a CNN on the CIFAR-10 dataset. See `05_projects/image_classification/train_cifar10.py`.
# - **Sentiment Analysis**: A basic NLP project for sentiment analysis. See `05_projects/nlp_sentiment/sentiment_analysis.py`.

# %% [markdown]
# ## 🎉 恭喜！
# You have completed the basics. Keep exploring, practicing, and building!
